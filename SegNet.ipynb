# %%
# !pip install pyunpack
# !pip install patool
from pyunpack import Archive
Archive('/kaggle/input/archieve')
# Out:
# Collecting pyunpack
#   Downloading pyunpack-0.3-py2.py3-none-any.whl.metadata (863 bytes)
# Collecting easyprocess (from pyunpack)
#   Downloading EasyProcess-1.1-py3-none-any.whl.metadata (855 bytes)
# Collecting entrypoint2 (from pyunpack)
#   Downloading entrypoint2-1.1-py2.py3-none-any.whl.metadata (1.0 kB)
# Downloading pyunpack-0.3-py2.py3-none-any.whl (4.1 kB)
# Downloading EasyProcess-1.1-py3-none-any.whl (8.7 kB)
# Downloading entrypoint2-1.1-py2.py3-none-any.whl (9.9 kB)
# Installing collected packages: entrypoint2, easyprocess, pyunpack
# Successfully installed easyprocess-1.1 entrypoint2-1.1 pyunpack-0.3
# Collecting patool
#   Downloading patool-2.2.0-py2.py3-none-any.whl.metadata (4.0 kB)
# Downloading patool-2.2.0-py2.py3-none-any.whl (96 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.0/96.0 kB 2.9 MB/s eta 0:00:00
# Installing collected packages: patool
# Successfully installed patool-2.2.0

# %%
import os
path2train="/kaggle/input/archieve/training_set/training_set"

imgsList = [pp for pp in os.listdir(path2train) if "Annotation" not in pp and (pp.endswith(".jpg") or pp.endswith(".png"))]
anntsList=[pp for pp in os.listdir(path2train) if "Annotation" in pp]
print("number of images:", len(imgsList))
print("number of annotations:", len(anntsList))
# Out:
# number of images: 999
# number of annotations: 999

# %%
import os

path2train = "/kaggle/input/archieve/training_set/training_set"

imgsList = [pp for pp in os.listdir(path2train) if "Annotation" not in pp and (pp.endswith(".jpg") or pp.endswith(".png"))]
anntsList = [pp for pp in os.listdir(path2train) if "Annotation" in pp]
print("number of images:", len(imgsList))
print("number of annotations:", len(anntsList))

import numpy as np

np.random.seed(2019)
rndImgs = np.random.choice(imgsList, 4)
rndImgs
# Out:
# number of images: 999
# number of annotations: 999
# array(['584_HC.png', '169_HC.png', '741_HC.png', '579_2HC.png'],
#       dtype='<U11')

# %%
import matplotlib.pylab as plt
from PIL import Image
from scipy import ndimage as ndi
from skimage.segmentation import mark_boundaries
from torchvision.transforms.functional import to_tensor, to_pil_image
import torch

def show_img_mask(img, mask):
    if torch.is_tensor(img):
        img=to_pil_image(img)
        mask=to_pil_image(mask)
        
        
    img_mask=mark_boundaries(np.array(img), 
                        np.array(mask),
                        outline_color=(0,1,0),
                        color=(0,1,0))
    plt.imshow(img_mask)

# %%
for fn in rndImgs:
    path2img = os.path.join(path2train, fn)
    path2annt= path2img.replace(".png", "_Annotation.png")
    img = Image.open(path2img)
    annt_edges = Image.open(path2annt)
    mask = ndi.binary_fill_holes(annt_edges)        

    plt.figure()
    plt.subplot(1, 3, 1) 
    plt.imshow(img, cmap="gray")

    plt.subplot(1, 3, 2) 
    plt.imshow(mask, cmap="gray")

    plt.subplot(1, 3, 3) 
    show_img_mask(img, mask)

# %%
plt.figure()
plt.subplot(1, 3, 1) 
plt.imshow(img, cmap="gray")
plt.axis('off')

plt.subplot(1, 3, 2) 
plt.imshow(mask, cmap="gray")
plt.axis('off')    

plt.subplot(1, 3, 3) 
show_img_mask(img, mask)
plt.axis('off')
# Out:
# (-0.5, 799.5, 539.5, -0.5)

# %%
from albumentations import (
    HorizontalFlip,
    VerticalFlip,    
    Compose,
    Resize,
)

h,w=128,192
transform_train = Compose([ Resize(h,w), 
                HorizontalFlip(p=0.5), 
                VerticalFlip(p=0.5), 
              ])


transform_val = Resize(h,w)

# %%
from torch.utils.data import Dataset
from PIL import Image

# %%
from torchvision.transforms.functional import to_tensor, to_pil_image

class fetal_dataset(Dataset):
    def __init__(self, path2data, transform=None):      

        imgsList = [pp for pp in os.listdir(path2data) if "Annotation" not in pp and (pp.endswith(".jpg") or pp.endswith(".png"))]
        anntsList=[pp for pp in os.listdir(path2train) if "Annotation" in pp]

        self.path2imgs = [os.path.join(path2data, fn) for fn in imgsList] 
        self.path2annts= [p2i.replace(".png", "_Annotation.png") for p2i in self.path2imgs]

        self.transform = transform
    
    def __len__(self):
        return len(self.path2imgs)
      
    def __getitem__(self, idx):
        path2img = self.path2imgs[idx]
        image = Image.open(path2img)

        path2annt = self.path2annts[idx]
        annt_edges = Image.open(path2annt)
        mask = ndi.binary_fill_holes(annt_edges)        
        
        image= np.array(image)
        mask=mask.astype("uint8")        

        if self.transform:
            augmented = self.transform(image=image, mask=mask)
            image = augmented['image']
            mask = augmented['mask']            

        image= to_tensor(image)            
        mask=255*to_tensor(mask)            
        return image, mask

# %%
fetal_ds1=fetal_dataset(path2train, transform=transform_train)
fetal_ds2=fetal_dataset(path2train, transform=transform_val)
print(len(fetal_ds1))
print(len(fetal_ds2))
# Out:
# 999
# 999

# %%
img,mask=fetal_ds1[0]
print(img.shape, img.type(),torch.max(img))
print(mask.shape, mask.type(),torch.max(mask))
# Out:
# torch.Size([1, 128, 192]) torch.FloatTensor tensor(0.9529)
# torch.Size([1, 128, 192]) torch.FloatTensor tensor(1.)

# %%
show_img_mask(img, mask)

# %%
from sklearn.model_selection import ShuffleSplit

sss = ShuffleSplit(n_splits=1, test_size=0.2, random_state=0)

indices=range(len(fetal_ds1))

for train_index, val_index in sss.split(indices):
    print(len(train_index))
    print("-"*10)
    print(len(val_index))
# Out:
# 799
# ----------
# 200

# %%
from torch.utils.data import Subset

train_ds=Subset(fetal_ds1,train_index)
print(len(train_ds))

val_ds=Subset(fetal_ds2,val_index)
print(len(val_ds))
# Out:
# 799
# 200

# %%
plt.figure(figsize=(5,5))
for img,mask in train_ds:
    show_img_mask(img,mask)
    break

# %%
plt.figure(figsize=(5,5))
for img,mask in val_ds:
    show_img_mask(img,mask)
    break

# %%
from torch.utils.data import DataLoader
train_dl = DataLoader(train_ds, batch_size=4, shuffle=True, pin_memory=True)
val_dl = DataLoader(val_ds, batch_size=8, shuffle=False, pin_memory=True)

# %%
for img_b, mask_b in train_dl:
    print(img_b.shape,img_b.dtype)
    print(mask_b.shape, mask_b.dtype)
    break
# Out:
# torch.Size([4, 1, 128, 192]) torch.float32
# torch.Size([4, 1, 128, 192]) torch.float32

# %%
for img_b, mask_b in val_dl:
    print(img_b.shape,img_b.dtype)
    print(mask_b.shape, mask_b.dtype)
    break
# Out:
# torch.Size([8, 1, 128, 192]) torch.float32
# torch.Size([8, 1, 128, 192]) torch.float32

# %%
torch.max(img_b)
# Out:
# tensor(0.9961)

# %%
import torch.nn as nn
import torch.nn.functional as F

# %%
class SegNet(nn.Module):
    def __init__(self, params):
        super(SegNet, self).__init__()
        
        C_in, H_in, W_in=params["input_shape"]
        init_f=params["initial_filters"] 
        num_outputs=params["num_outputs"] 

        self.conv1 = nn.Conv2d(C_in, init_f, kernel_size=3,stride=1,padding=1)
        self.conv2 = nn.Conv2d(init_f, 2*init_f, kernel_size=3,stride=1,padding=1)
        self.conv3 = nn.Conv2d(2*init_f, 4*init_f, kernel_size=3,padding=1)
        self.conv4 = nn.Conv2d(4*init_f, 8*init_f, kernel_size=3,padding=1)
        self.conv5 = nn.Conv2d(8*init_f, 16*init_f, kernel_size=3,padding=1)

        self.upsample = nn.Upsample(scale_factor=2, mode='bilinear', align_corners=True)

        self.conv_up1 = nn.Conv2d(16*init_f, 8*init_f, kernel_size=3,padding=1)
        self.conv_up2 = nn.Conv2d(8*init_f, 4*init_f, kernel_size=3,padding=1)
        self.conv_up3 = nn.Conv2d(4*init_f, 2*init_f, kernel_size=3,padding=1)
        self.conv_up4 = nn.Conv2d(2*init_f, init_f, kernel_size=3,padding=1)
        
        self.conv_out = nn.Conv2d(init_f, num_outputs , kernel_size=3,padding=1)    
    
    def forward(self, x):
        
        x = self.conv1(x)
        x = F.relu(x)
        x = F.max_pool2d(x, 2, 2)

        x = self.conv2(x)
        x = F.relu(x)
        x = F.max_pool2d(x, 2, 2)

        x = self.conv3(x)
        x = F.relu(x)
        x = F.max_pool2d(x, 2, 2)

        x = self.conv4(x)
        x = F.relu(x)
        x = F.max_pool2d(x, 2, 2)
        x = self.conv5(x)
        x = F.relu(x)

        x=self.upsample(x)
        x = self.conv_up1(x)
        x = F.relu(x)

        x=self.upsample(x)
        x = self.conv_up2(x)
        x = F.relu(x)
        
        x=self.upsample(x)
        x = self.conv_up3(x)
        x = F.relu(x)
        
        x=self.upsample(x)
        x = self.conv_up4(x)
        x = F.relu(x)

        x = self.conv_out(x)
        
        return x

# %%
params_model={
        "input_shape": (1,h,w),
        "initial_filters": 16, 
        "num_outputs": 1,
            }

model = SegNet(params_model)

# %%
import torch
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model=model.to(device)

# %%
print(model)
# Out:
# SegNet(
#   (conv1): Conv2d(1, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv2): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv4): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv5): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (upsample): Upsample(scale_factor=2.0, mode='bilinear')
#   (conv_up1): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv_up2): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv_up3): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv_up4): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv_out): Conv2d(16, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# )

# %%
# !pip install torchsummary
# Out:
# /opt/conda/lib/python3.10/pty.py:89: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid, fd = os.forkpty()
# Collecting torchsummary
#   Downloading torchsummary-1.5.1-py3-none-any.whl.metadata (296 bytes)
# Downloading torchsummary-1.5.1-py3-none-any.whl (2.8 kB)
# Installing collected packages: torchsummary
# Successfully installed torchsummary-1.5.1

# %%
from torchsummary import summary
summary(model, input_size=(1, h, w))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 16, 128, 192]             160
#             Conv2d-2           [-1, 32, 64, 96]           4,640
#             Conv2d-3           [-1, 64, 32, 48]          18,496
#             Conv2d-4          [-1, 128, 16, 24]          73,856
#             Conv2d-5           [-1, 256, 8, 12]         295,168
#           Upsample-6          [-1, 256, 16, 24]               0
#             Conv2d-7          [-1, 128, 16, 24]         295,040
#           Upsample-8          [-1, 128, 32, 48]               0
#             Conv2d-9           [-1, 64, 32, 48]          73,792
#          Upsample-10           [-1, 64, 64, 96]               0
#            Conv2d-11           [-1, 32, 64, 96]          18,464
#          Upsample-12         [-1, 32, 128, 192]               0
#            Conv2d-13         [-1, 16, 128, 192]           4,624
#            Conv2d-14          [-1, 1, 128, 192]             145
# ================================================================
# Total params: 784,385
# Trainable params: 784,385
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.09
# Forward/backward pass size (MB): 22.88
# Params size (MB): 2.99
# Estimated Total Size (MB): 25.96
# ----------------------------------------------------------------

# %%
def dice_loss(pred, target, smooth = 1e-5):

    intersection = (pred * target).sum(dim=(2,3))
    union= pred.sum(dim=(2,3)) + target.sum(dim=(2,3)) 
    
    dice= 2.0 * (intersection + smooth) / (union+ smooth)    
    loss = 1.0 - dice
    
    return loss.sum(), dice.sum()

# %%
import torch.nn.functional as F

def loss_func(pred, target):
    bce = F.binary_cross_entropy_with_logits(pred, target,  reduction='sum')
    
    pred= torch.sigmoid(pred)
    dlv, _ = dice_loss(pred, target)
    
    loss = bce  + dlv

    return loss

# %%
for img_v,mask_v in val_dl:
    mask_v= mask_v[8:]
    break

for img_t,mask_t in train_dl:
    break
    


print(dice_loss(mask_v,mask_v))
loss_func(mask_v,torch.zeros_like(mask_v))
# Out:
# (tensor(0.), tensor(0.))
# tensor(0.)

# %%
import torchvision

def metrics_batch(pred, target):
    pred= torch.sigmoid(pred)
    _, metric=dice_loss(pred, target)
    
    return metric

# %%
def loss_batch(loss_func, output, target, opt=None):   
    loss = loss_func(output, target)
    
    with torch.no_grad():
        pred= torch.sigmoid(output)
        _, metric_b=dice_loss(pred, target)
    
    if opt is not None:
        opt.zero_grad()
        loss.backward()
        opt.step()

    return loss.item(), metric_b

# %%
from torch import optim
opt = optim.Adam(model.parameters(), lr=3e-4)

# %%
from torch.optim.lr_scheduler import ReduceLROnPlateau
lr_scheduler = ReduceLROnPlateau(opt, mode='min',factor=0.5, patience=20,verbose=1)

# %%
def get_lr(opt):
    for param_group in opt.param_groups:
        return param_group['lr']

current_lr=get_lr(opt)
print('current lr={}'.format(current_lr))
# Out:
# current lr=0.0003

# %%
def loss_epoch(model,loss_func,dataset_dl,sanity_check=False,opt=None):
    running_loss=0.0
    running_metric=0.0
    len_data=len(dataset_dl.dataset)

    for xb, yb in dataset_dl:
        xb=xb.to(device)
        yb=yb.to(device)
        
        output=model(xb)
        loss_b, metric_b=loss_batch(loss_func, output, yb, opt)
        running_loss += loss_b
        
        if metric_b is not None:
            running_metric+=metric_b

        if sanity_check is True:
            break
    
    loss=running_loss/float(len_data)  
    
    metric=running_metric/float(len_data)
    
    return loss, metric

# %%
import copy
import time
def train_val(model, params):
    num_epochs=params["num_epochs"]
    loss_func=params["loss_func"]
    opt=params["optimizer"]
    train_dl=params["train_dl"]
    val_dl=params["val_dl"]
    sanity_check=params["sanity_check"]
    lr_scheduler=params["lr_scheduler"]
    path2weights=params["path2weights"]
    
    loss_history={
        "train": [],
        "val": []}
    
    metric_history={
        "train": [],
         "val": []}    
    
    
    best_model_wts = copy.deepcopy(model.state_dict())
    best_loss=float('inf')    
    
    for epoch in range(num_epochs):
        current_lr=get_lr(opt)
        print('Epoch {}/{}, current lr={}'.format(epoch, num_epochs - 1, current_lr))   
        
        start_time = time.time()
        
        model.train()
        train_loss, train_metric=loss_epoch(model,loss_func,train_dl,sanity_check,opt)

        loss_history["train"].append(train_loss)
        metric_history["train"].append(train_metric)
        
        model.eval()
        with torch.no_grad():
            val_loss, val_metric=loss_epoch(model,loss_func,val_dl,sanity_check)
             
        loss_history["val"].append(val_loss)
        metric_history["val"].append(val_metric)   
        
        if val_loss < best_loss:
            best_loss = val_loss
            best_model_wts = copy.deepcopy(model.state_dict())
            
            torch.save(model.state_dict(), path2weights)
            print("Copied best model weights!")
            
        lr_scheduler.step(val_loss)
        if current_lr != get_lr(opt):
            print("Loading best model weights!")
            model.load_state_dict(best_model_wts) 
            
        epoch_time = time.time() - start_time
        print("train loss: %.6f, dice: %.2f" %(train_loss,100*train_metric))
        print("val loss: %.6f, dice: %.2f" %(val_loss,100*val_metric))
        print("Epoch Time: %.2f seconds".format(epoch_time))
        print("-"*10) 
            

    model.load_state_dict(best_model_wts)
    return model, loss_history, metric_history

# %%
opt = optim.Adam(model.parameters(), lr=3e-4)
lr_scheduler = ReduceLROnPlateau(opt, mode='min',factor=0.5, patience=20,verbose=1)

path2models= "./models/"
if not os.path.exists(path2models):
        os.mkdir(path2models)

params_train={
    "num_epochs": 20,
    "optimizer": opt,
    "loss_func": loss_func,
    "train_dl": train_dl,
    "val_dl": val_dl,
    "sanity_check": False,
    "lr_scheduler": lr_scheduler,
    "path2weights": path2models+"weights.pt",
}

model,loss_hist,metric_hist=train_val(model,params_train)
# Out:
# Epoch 0/99, current lr=0.0003
# Copied best model weights!
# train loss: 10803.934881, dice: 46.67
# val loss: 7100.064297, dice: 66.43
# Epoch Time: %.2f seconds
# ----------
# Epoch 1/99, current lr=0.0003
# Copied best model weights!
# train loss: 5956.158063, dice: 71.80
# val loss: 5026.666357, dice: 77.21
# Epoch Time: %.2f seconds
# ----------
# Epoch 2/99, current lr=0.0003
# Copied best model weights!
# train loss: 4714.514725, dice: 77.19
# val loss: 4172.988096, dice: 79.72
# Epoch Time: %.2f seconds
# ----------
# Epoch 3/99, current lr=0.0003
# Copied best model weights!
# train loss: 3949.321271, dice: 80.33
# val loss: 3544.699404, dice: 80.19
# Epoch Time: %.2f seconds
# ----------
# Epoch 4/99, current lr=0.0003
# train loss: 3375.723844, dice: 82.81
# val loss: 3650.640645, dice: 81.91
# Epoch Time: %.2f seconds
# ----------
# Epoch 5/99, current lr=0.0003
# Copied best model weights!
# train loss: 3001.418841, dice: 84.66
# val loss: 3397.048779, dice: 82.50
# Epoch Time: %.2f seconds
# ----------
# Epoch 6/99, current lr=0.0003
# Copied best model weights!
# train loss: 2622.141731, dice: 86.67
# val loss: 2525.778638, dice: 86.95
# Epoch Time: %.2f seconds
# ----------
# Epoch 7/99, current lr=0.0003
# Copied best model weights!
# train loss: 2218.854467, dice: 88.75
# val loss: 2218.030674, dice: 89.55
# Epoch Time: %.2f seconds
# ----------
# Epoch 8/99, current lr=0.0003
# Copied best model weights!
# train loss: 2048.701968, dice: 89.80
# val loss: 2131.708306, dice: 88.15
# Epoch Time: %.2f seconds
# ----------
# Epoch 9/99, current lr=0.0003
# Copied best model weights!
# train loss: 1916.259053, dice: 90.53
# val loss: 1959.708489, dice: 91.13
# Epoch Time: %.2f seconds
# ----------
# Epoch 10/99, current lr=0.0003
# Copied best model weights!
# train loss: 1754.228276, dice: 91.24
# val loss: 1833.847854, dice: 91.19
# Epoch Time: %.2f seconds
# ----------
# Epoch 11/99, current lr=0.0003
# Copied best model weights!
# train loss: 1662.651954, dice: 91.95
# val loss: 1647.494497, dice: 92.39
# Epoch Time: %.2f seconds
# ----------
# Epoch 12/99, current lr=0.0003
# Copied best model weights!
# train loss: 1542.198948, dice: 92.55
# val loss: 1638.493696, dice: 91.48
# Epoch Time: %.2f seconds
# ----------
# Epoch 13/99, current lr=0.0003
# Copied best model weights!
# train loss: 1466.674251, dice: 92.83
# val loss: 1467.673687, dice: 92.80
# Epoch Time: %.2f seconds
# ----------
# Epoch 14/99, current lr=0.0003
# Copied best model weights!
# train loss: 1475.033102, dice: 92.91
# val loss: 1446.934426, dice: 92.61
# Epoch Time: %.2f seconds
# ----------
# Epoch 15/99, current lr=0.0003
# train loss: 1485.008082, dice: 92.90
# val loss: 1553.536628, dice: 92.14
# Epoch Time: %.2f seconds
# ----------
# Epoch 16/99, current lr=0.0003
# train loss: 1534.413641, dice: 92.58
# val loss: 1680.203696, dice: 91.34
# Epoch Time: %.2f seconds
# ----------
# Epoch 17/99, current lr=0.0003
# train loss: 1381.026989, dice: 93.23
# val loss: 1471.278135, dice: 92.96
# Epoch Time: %.2f seconds
# ----------
# Epoch 18/99, current lr=0.0003
# Copied best model weights!
# train loss: 1349.854336, dice: 93.49
# val loss: 1343.558608, dice: 93.22
# Epoch Time: %.2f seconds
# ----------
# Epoch 19/99, current lr=0.0003
# train loss: 1292.432197, dice: 93.71
# val loss: 1375.724177, dice: 93.54
# Epoch Time: %.2f seconds
# ----------
# Epoch 20/99, current lr=0.0003
# train loss: 1266.545697, dice: 93.99
# val loss: 1515.147065, dice: 92.40
# Epoch Time: %.2f seconds
# ----------
# Epoch 21/99, current lr=0.0003
# Copied best model weights!
# train loss: 1297.295410, dice: 93.77
# val loss: 1292.653411, dice: 93.62
# Epoch Time: %.2f seconds
# ----------
# Epoch 22/99, current lr=0.0003
# train loss: 1235.023593, dice: 93.94
# val loss: 1439.643945, dice: 92.54
# Epoch Time: %.2f seconds
# ----------
# Epoch 23/99, current lr=0.0003
# train loss: 1217.209820, dice: 94.18
# val loss: 1297.939150, dice: 94.00
# Epoch Time: %.2f seconds
# ----------
# Epoch 24/99, current lr=0.0003
# train loss: 1187.152100, dice: 94.28
# val loss: 1336.136104, dice: 93.24
# Epoch Time: %.2f seconds
# ----------
# Epoch 25/99, current lr=0.0003
# Copied best model weights!
# train loss: 1188.904413, dice: 94.09
# val loss: 1230.719878, dice: 94.21
# Epoch Time: %.2f seconds
# ----------
# Epoch 26/99, current lr=0.0003
# train loss: 1152.175030, dice: 94.61
# val loss: 1723.940796, dice: 92.76
# Epoch Time: %.2f seconds
# ----------
# Epoch 27/99, current lr=0.0003
# train loss: 1146.265494, dice: 94.38
# val loss: 1859.448425, dice: 91.98
# Epoch Time: %.2f seconds
# ----------
# Epoch 28/99, current lr=0.0003
# train loss: 1127.064346, dice: 94.46
# val loss: 1266.336658, dice: 94.15
# Epoch Time: %.2f seconds
# ----------
# Epoch 29/99, current lr=0.0003
# train loss: 1040.239528, dice: 94.80
# val loss: 1323.968364, dice: 92.82
# Epoch Time: %.2f seconds
# ----------
# Epoch 30/99, current lr=0.0003
# Copied best model weights!
# train loss: 1064.649792, dice: 94.75
# val loss: 1197.383560, dice: 94.33
# Epoch Time: %.2f seconds
# ----------
# Epoch 31/99, current lr=0.0003
# train loss: 1006.483371, dice: 95.02
# val loss: 1306.373713, dice: 93.55
# Epoch Time: %.2f seconds
# ----------
# Epoch 32/99, current lr=0.0003
# Copied best model weights!
# train loss: 1027.125190, dice: 94.76
# val loss: 1189.236116, dice: 94.66
# Epoch Time: %.2f seconds
# ----------
# Epoch 33/99, current lr=0.0003
# train loss: 1100.072054, dice: 94.78
# val loss: 1255.658779, dice: 94.08
# Epoch Time: %.2f seconds
# ----------
# Epoch 34/99, current lr=0.0003
# train loss: 1003.961625, dice: 95.04
# val loss: 1259.998115, dice: 94.49
# Epoch Time: %.2f seconds
# ----------
# Epoch 35/99, current lr=0.0003
# train loss: 971.292830, dice: 95.14
# val loss: 1270.841968, dice: 94.47
# Epoch Time: %.2f seconds
# ----------
# Epoch 36/99, current lr=0.0003
# train loss: 964.079980, dice: 95.10
# val loss: 1380.951702, dice: 93.58
# Epoch Time: %.2f seconds
# ----------
# Epoch 37/99, current lr=0.0003
# Copied best model weights!
# train loss: 951.531345, dice: 95.05
# val loss: 1173.768020, dice: 94.91
# Epoch Time: %.2f seconds
# ----------
# Epoch 38/99, current lr=0.0003
# train loss: 915.474636, dice: 95.35
# val loss: 1201.915742, dice: 94.76
# Epoch Time: %.2f seconds
# ----------
# Epoch 39/99, current lr=0.0003
# train loss: 933.959081, dice: 95.14
# val loss: 1439.466638, dice: 93.50
# Epoch Time: %.2f seconds
# ----------
# Epoch 40/99, current lr=0.0003
# train loss: 1000.153726, dice: 94.97
# val loss: 1334.914990, dice: 94.64
# Epoch Time: %.2f seconds
# ----------
# Epoch 41/99, current lr=0.0003
# train loss: 839.866469, dice: 95.57
# val loss: 1226.586904, dice: 94.83
# Epoch Time: %.2f seconds
# ----------
# Epoch 42/99, current lr=0.0003
# train loss: 786.166281, dice: 95.80
# val loss: 1186.886399, dice: 94.90
# Epoch Time: %.2f seconds
# ----------
# Epoch 43/99, current lr=0.0003
# train loss: 922.947539, dice: 95.25
# val loss: 1298.630830, dice: 94.41
# Epoch Time: %.2f seconds
# ----------
# Epoch 44/99, current lr=0.0003
# train loss: 828.133645, dice: 95.60
# val loss: 1240.242163, dice: 94.91
# Epoch Time: %.2f seconds
# ----------
# Epoch 45/99, current lr=0.0003
# train loss: 790.940494, dice: 95.76
# val loss: 1224.503145, dice: 94.93
# Epoch Time: %.2f seconds
# ----------
# Epoch 46/99, current lr=0.0003
# Copied best model weights!
# train loss: 791.187311, dice: 95.83
# val loss: 1168.789343, dice: 94.90
# Epoch Time: %.2f seconds
# ----------
# Epoch 47/99, current lr=0.0003
# train loss: 841.874679, dice: 95.71
# val loss: 1185.602151, dice: 94.83
# Epoch Time: %.2f seconds
# ----------
# Epoch 48/99, current lr=0.0003
# train loss: 755.650882, dice: 95.95
# val loss: 1198.747644, dice: 94.98
# Epoch Time: %.2f seconds
# ----------
# Epoch 49/99, current lr=0.0003
# train loss: 949.268215, dice: 95.24
# val loss: 1343.962429, dice: 94.16
# Epoch Time: %.2f seconds
# ----------
# Epoch 50/99, current lr=0.0003
# train loss: 902.451107, dice: 95.34
# val loss: 1298.332813, dice: 94.31
# Epoch Time: %.2f seconds
# ----------
# Epoch 51/99, current lr=0.0003
# train loss: 824.708945, dice: 95.65
# val loss: 1485.711663, dice: 93.69
# Epoch Time: %.2f seconds
# ----------
# Epoch 52/99, current lr=0.0003
# train loss: 799.244711, dice: 95.70
# val loss: 1249.186709, dice: 94.86
# Epoch Time: %.2f seconds
# ----------
# Epoch 53/99, current lr=0.0003
# train loss: 839.950115, dice: 95.64
# val loss: 1389.020500, dice: 94.35
# Epoch Time: %.2f seconds
# ----------
# Epoch 54/99, current lr=0.0003
# train loss: 734.934276, dice: 96.02
# val loss: 1220.174304, dice: 94.92
# Epoch Time: %.2f seconds
# ----------
# Epoch 55/99, current lr=0.0003
# train loss: 706.232121, dice: 96.18
# val loss: 1292.873772, dice: 94.95
# Epoch Time: %.2f seconds
# ----------
# Epoch 56/99, current lr=0.0003
# train loss: 706.469894, dice: 96.17
# val loss: 1272.821255, dice: 95.00
# Epoch Time: %.2f seconds
# ----------
# Epoch 57/99, current lr=0.0003
# train loss: 675.239201, dice: 96.34
# val loss: 1238.669531, dice: 95.19
# Epoch Time: %.2f seconds
# ----------
# Epoch 58/99, current lr=0.0003
# train loss: 712.829247, dice: 96.32
# val loss: 3895.087104, dice: 89.23
# Epoch Time: %.2f seconds
# ----------
# Epoch 59/99, current lr=0.0003
# train loss: 947.968307, dice: 95.14
# val loss: 1274.750457, dice: 94.88
# Epoch Time: %.2f seconds
# ----------
# Epoch 60/99, current lr=0.0003
# train loss: 688.062416, dice: 96.27
# val loss: 1260.062737, dice: 95.17
# Epoch Time: %.2f seconds
# ----------
# Epoch 61/99, current lr=0.0003
# train loss: 687.310365, dice: 96.29
# val loss: 1212.982859, dice: 95.18
# Epoch Time: %.2f seconds
# ----------
# Epoch 62/99, current lr=0.0003
# train loss: 643.496558, dice: 96.53
# val loss: 1192.134897, dice: 95.25
# Epoch Time: %.2f seconds
# ----------
# Epoch 63/99, current lr=0.0003
# train loss: 658.385031, dice: 96.48
# val loss: 1302.728518, dice: 95.15
# Epoch Time: %.2f seconds
# ----------
# Epoch 64/99, current lr=0.0003
# train loss: 658.146865, dice: 96.47
# val loss: 1247.113896, dice: 95.26
# Epoch Time: %.2f seconds
# ----------
# Epoch 65/99, current lr=0.0003
# train loss: 631.992591, dice: 96.57
# val loss: 1303.053345, dice: 95.30
# Epoch Time: %.2f seconds
# ----------
# Epoch 66/99, current lr=0.0003
# train loss: 631.391675, dice: 96.58
# val loss: 1256.426978, dice: 95.40
# Epoch Time: %.2f seconds
# ----------
# Epoch 67/99, current lr=0.0003
# Epoch 00068: reducing learning rate of group 0 to 1.5000e-04.
# Loading best model weights!
# train loss: 625.757667, dice: 96.59
# val loss: 1500.187832, dice: 94.97
# Epoch Time: %.2f seconds
# ----------
# Epoch 68/99, current lr=0.00015
# train loss: 730.767573, dice: 96.06
# val loss: 1186.290100, dice: 95.17
# Epoch Time: %.2f seconds
# ----------
# Epoch 69/99, current lr=0.00015
# train loss: 715.180765, dice: 96.13
# val loss: 1222.433965, dice: 95.13
# Epoch Time: %.2f seconds
# ----------
# Epoch 70/99, current lr=0.00015
# train loss: 801.351698, dice: 95.93
# val loss: 1200.300925, dice: 95.15
# Epoch Time: %.2f seconds
# ----------
# Epoch 71/99, current lr=0.00015
# train loss: 706.852736, dice: 96.19
# val loss: 1184.136565, dice: 95.14
# Epoch Time: %.2f seconds
# ----------
# Epoch 72/99, current lr=0.00015
# train loss: 697.036893, dice: 96.25
# val loss: 1174.103823, dice: 95.11
# Epoch Time: %.2f seconds
# ----------
# Epoch 73/99, current lr=0.00015
# train loss: 683.026192, dice: 96.29
# val loss: 1231.204529, dice: 95.35
# Epoch Time: %.2f seconds
# ----------
# Epoch 74/99, current lr=0.00015
# train loss: 718.775592, dice: 96.27
# val loss: 1247.760791, dice: 94.95
# Epoch Time: %.2f seconds
# ----------
# Epoch 75/99, current lr=0.00015
# train loss: 718.196880, dice: 96.22
# val loss: 1273.437476, dice: 94.93
# Epoch Time: %.2f seconds
# ----------
# Epoch 76/99, current lr=0.00015
# train loss: 667.795251, dice: 96.39
# val loss: 1317.920337, dice: 95.05
# Epoch Time: %.2f seconds
# ----------
# Epoch 77/99, current lr=0.00015
# train loss: 651.665821, dice: 96.48
# val loss: 1246.068604, dice: 95.28
# Epoch Time: %.2f seconds
# ----------
# Epoch 78/99, current lr=0.00015
# train loss: 650.660201, dice: 96.49
# val loss: 1317.858723, dice: 95.09
# Epoch Time: %.2f seconds
# ----------
# Epoch 79/99, current lr=0.00015
# train loss: 628.810393, dice: 96.58
# val loss: 1263.547876, dice: 95.28
# Epoch Time: %.2f seconds
# ----------
# Epoch 80/99, current lr=0.00015
# train loss: 629.800089, dice: 96.60
# val loss: 1300.601152, dice: 95.16
# Epoch Time: %.2f seconds
# ----------
# Epoch 81/99, current lr=0.00015
# train loss: 627.160497, dice: 96.61
# val loss: 1338.489744, dice: 95.22
# Epoch Time: %.2f seconds
# ----------
# Epoch 82/99, current lr=0.00015
# train loss: 611.049377, dice: 96.69
# val loss: 1279.359570, dice: 95.26
# Epoch Time: %.2f seconds
# ----------
# Epoch 83/99, current lr=0.00015
# train loss: 644.613871, dice: 96.58
# val loss: 1436.868560, dice: 95.13
# Epoch Time: %.2f seconds
# ----------
# Epoch 84/99, current lr=0.00015
# train loss: 610.434795, dice: 96.67
# val loss: 1375.967561, dice: 95.28
# Epoch Time: %.2f seconds
# ----------
# Epoch 85/99, current lr=0.00015
# train loss: 598.925831, dice: 96.75
# val loss: 1379.028079, dice: 95.31
# Epoch Time: %.2f seconds
# ----------
# Epoch 86/99, current lr=0.00015
# train loss: 594.658346, dice: 96.77
# val loss: 1359.198308, dice: 95.38
# Epoch Time: %.2f seconds
# ----------
# Epoch 87/99, current lr=0.00015
# train loss: 591.007638, dice: 96.80
# val loss: 1347.333010, dice: 95.28
# Epoch Time: %.2f seconds
# ----------
# Epoch 88/99, current lr=0.00015
# Epoch 00089: reducing learning rate of group 0 to 7.5000e-05.
# Loading best model weights!
# train loss: 586.405847, dice: 96.81
# val loss: 1361.926431, dice: 95.42
# Epoch Time: %.2f seconds
# ----------
# Epoch 89/99, current lr=7.5e-05
# Copied best model weights!
# train loss: 733.639435, dice: 96.03
# val loss: 1168.302468, dice: 95.15
# Epoch Time: %.2f seconds
# ----------
# Epoch 90/99, current lr=7.5e-05
# train loss: 699.169262, dice: 96.24
# val loss: 1209.922632, dice: 95.10
# Epoch Time: %.2f seconds
# ----------
# Epoch 91/99, current lr=7.5e-05
# train loss: 732.110491, dice: 96.17
# val loss: 1202.435352, dice: 95.13
# Epoch Time: %.2f seconds
# ----------
# Epoch 92/99, current lr=7.5e-05
# train loss: 691.645254, dice: 96.32
# val loss: 1224.499880, dice: 95.19
# Epoch Time: %.2f seconds
# ----------
# Epoch 93/99, current lr=7.5e-05
# train loss: 682.778357, dice: 96.34
# val loss: 1187.014207, dice: 95.18
# Epoch Time: %.2f seconds
# ----------
# Epoch 94/99, current lr=7.5e-05
# Copied best model weights!
# train loss: 708.119725, dice: 96.36
# val loss: 1156.512866, dice: 94.94
# Epoch Time: %.2f seconds
# ----------
# Epoch 95/99, current lr=7.5e-05
# train loss: 689.829584, dice: 96.34
# val loss: 1228.591128, dice: 95.23
# Epoch Time: %.2f seconds
# ----------
# Epoch 96/99, current lr=7.5e-05
# train loss: 666.500005, dice: 96.42
# val loss: 1231.698430, dice: 95.16
# Epoch Time: %.2f seconds
# ----------
# Epoch 97/99, current lr=7.5e-05
# train loss: 645.672445, dice: 96.50
# val loss: 1224.501296, dice: 95.23
# Epoch Time: %.2f seconds
# ----------
# Epoch 98/99, current lr=7.5e-05
# train loss: 655.108363, dice: 96.50
# val loss: 1231.077952, dice: 95.18
# Epoch Time: %.2f seconds
# ----------
# Epoch 99/99, current lr=7.5e-05
# train loss: 648.654985, dice: 96.51
# val loss: 1260.949417, dice: 95.29
# Epoch Time: %.2f seconds
# ----------

# %%
num_epochs=params_train["num_epochs"]

plt.title("Train-Val Loss")
plt.plot(range(1,num_epochs+1),loss_hist["train"],label="train")
plt.plot(range(1,num_epochs+1),loss_hist["val"],label="val")
plt.ylabel("Loss")
plt.xlabel("Training Epochs")
plt.legend()
plt.show()

# %%
# plot accuracy progress
plt.title("Train-Val Accuracy")
plt.plot(range(1,num_epochs+1),metric_hist["train"],label="train")
plt.plot(range(1,num_epochs+1),metric_hist["val"],label="val")
plt.ylabel("Accuracy")
plt.xlabel("Training Epochs")
plt.legend()
plt.show()
